# %% [markdown]
# ### Knowledge graph exploration

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\aprog\OneDrive\Documents\Git_repos\PLTR_x_LlamaIndex\outputs\triplet_relations\8k_10k_kg_relations.csv')
display(df)
# Out:
#                                   subject             predicate  \
# 0              Palantir Technologies Inc.                Issues
# 1                    Class A Common Stock   Traded under symbol
# 2                                    PLTR             Listed on
# 3              Palantir Technologies Inc.                 Files
# 4                              10K report          Submitted to
# ...                                   ...                   ...
# 4994                    Twelfth Amendment                Amends
# 4995                         Exhibit 10.1              Contains
# 4996                Palantir Technologies   No Outstanding Debt
# 4997                    Alexander C. Karp     Executive Officer
# 4998  Morgan Stanley Senior Funding, Inc.  Administrative Agent
#
#                                                 object        filename  \
# 0                                 Class A Common Stock     2024 FY.pdf
# ...
